# %%
library(RGtk2)
library(devtools)
library(gWidgets2RGtk2)
library(rMSI)
# Out:
# Loading required package: usethis
#
# Loading required package: cairoDevice
#
# R session is headless; GTK+ not initialized.

# %%
foo <- rMSI::OpenMSI()
# Out:
# Error in guiToolkit(): Can't load RGtk2
# Traceback:
#
# 1. rMSI::OpenMSI()
# 2. LoadTwoMsImages()
# 3. gWidgets2::gwindow("Load MSI data", visible = F, width = 600,
#  .     height = 200, parent = c(0.5 * RGtk2::gdkScreenWidth() -
#  .         300, 0.5 * RGtk2::gdkScreenHeight() - 100))
# 4. guiToolkit()
# 5. stop("Can't load RGtk2")

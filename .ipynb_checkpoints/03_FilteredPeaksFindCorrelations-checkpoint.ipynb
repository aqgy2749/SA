# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import glob
import os

# %%
df_K_RMS=pd.read_csv("/p1/data/jtian/SA/output/03_FilteredPeaksFindCorrelations/FilteredPeaks2.csv")
print(df_K_RMS.head(10))
# Out:
#         mz           0          15          30          45          60
# 0  57.0346    5.439641    6.107226    6.564998    6.888494    7.217203
# 1  58.0302    8.599435    9.050849    9.695848    9.858253   10.218597
# 2  59.0139   34.948009   40.570732   44.621750   47.503277   50.145832
# 3  67.0191    9.017411    9.695403   10.642975   11.168103   12.203849
# 4  71.0140  159.010345  166.835968  181.688141  193.540451  205.613632
# 5  71.0503    3.900091    5.021873    5.800976    6.295655    6.769176
# 6  72.0091   13.210133   14.482081   16.041576   16.998287   18.016367
# 7  72.0170    5.159153    5.418654    5.938540    6.332651    6.620831
# 8  73.0294   52.655033   63.078827   71.710571   76.554489   82.528931
# 9  74.0246   31.124227   36.245281   41.411957   44.302441   47.305695

# %%
#使用sklearn计算R²
def calculate_r2_sklearn(df, x_values=[0, 15, 30, 45, 60]):
    # 将x_values转换为二维数组
    X = np.array(x_values).reshape(-1, 1)
    r2_scores = []
    
    for idx, row in df.iterrows():
        y_values = row[1:].values
        
        # 创建线性回归模型
        model = LinearRegression()
        model.fit(X, y_values)
        
        # 预测并计算R²
        y_pred = model.predict(X)
        r2 = r2_score(y_values, y_pred)
        r2_scores.append(r2)
    
    return r2_scores

# %%
r2_values_RMS = calculate_r2_sklearn(df_K_RMS)
df_K_RMS['R2'] = r2_values_RMS

# %%
print(df_K_RMS.head(10))
# Out:
#         mz           0          15          30          45          60  \
# 0  57.0346    5.439641    6.107226    6.564998    6.888494    7.217203
# 1  58.0302    8.599435    9.050849    9.695848    9.858253   10.218597
# 2  59.0139   34.948009   40.570732   44.621750   47.503277   50.145832
# 3  67.0191    9.017411    9.695403   10.642975   11.168103   12.203849
# 4  71.0140  159.010345  166.835968  181.688141  193.540451  205.613632
# 5  71.0503    3.900091    5.021873    5.800976    6.295655    6.769176
# 6  72.0091   13.210133   14.482081   16.041576   16.998287   18.016367
# 7  72.0170    5.159153    5.418654    5.938540    6.332651    6.620831
# 8  73.0294   52.655033   63.078827   71.710571   76.554489   82.528931
# 9  74.0246   31.124227   36.245281   41.411957   44.302441   47.305695
#
#          R2
# 0  0.973201
# 1  0.965858
# 2  0.973367
# 3  0.991995
# 4  0.993577
# 5  0.962895
# 6  0.991392
# 7  0.989179
# 8  0.976268
# 9  0.979929

# %%
print(len(df_K_RMS[df_K_RMS.R2>0.9]))
print(len(df_K_RMS[df_K_RMS.R2>0.95]))
# Out:
# 744
# 438

# %%
mz09=df_K_RMS[df_K_RMS.R2>0.9][['mz','R2']]
mz09.to_csv('/p1/data/jtian/SA/output/03_FilteredPeaksFindCorrelations/FilteredPeaks09_K.csv', index=False)
